# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
Crimes = pd.read_csv('D:/CUSTOM WORK/Python Practice/CSV Data/Crimes.csv')
display(Crimes.head(10))
# Out:
#          ID Case Number           Date                                Block
# 0  11798117    JC397040  8/17/19 23:59                      058XX W EDDY ST  \
# 1  11798223    JC397365  8/17/19 23:59                      007XX E 87TH ST
# 2  11797883    JC396936  8/17/19 23:57                      022XX W 50TH PL
# 3  11797909    JC397003  8/17/19 23:55                 086XX S PHILLIPS AVE
# 4  11797926    JC396947  8/17/19 23:45            079XX S SOUTH CHICAGO AVE
# 5  11797877    JC396925  8/17/19 23:42                023XX N MILWAUKEE AVE
# 6  11797907    JC396922  8/17/19 23:42  061XX S DR MARTIN LUTHER KING JR DR
# 7  11798114    JC396931  8/17/19 23:40                     011XX S CANAL ST
# 8  11797953    JC396974  8/17/19 23:39               014XX N NORTH PARK AVE
# 9  11797975    JC396957  8/17/19 23:33                      044XX W 26TH ST
#
#    IUCR       Primary Type                     Description
# 0   820              THEFT                  $500 AND UNDER  \
# 1  1310    CRIMINAL DAMAGE                     TO PROPERTY
# 2  143A  WEAPONS VIOLATION        UNLAWFUL POSS OF HANDGUN
# 3  143A  WEAPONS VIOLATION        UNLAWFUL POSS OF HANDGUN
# 4   460            BATTERY                          SIMPLE
# 5   520            ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 6  041A            BATTERY             AGGRAVATED: HANDGUN
# 7   460            BATTERY                          SIMPLE
# 8  2170          NARCOTICS    POSSESSION OF DRUG EQUIPMENT
# 9   313            ROBBERY   ARMED: OTHER DANGEROUS WEAPON
#
#            Location Description  Arrest  Domestic  Beat  District  Ward
# 0                        STREET    True     False  1633        16  36.0  \
# 1           TAVERN/LIQUOR STORE   False     False   632         6   6.0
# 2                      SIDEWALK   False     False   931         9  15.0
# 3                         ALLEY   False     False   423         4   7.0
# 4                      SIDEWALK    True     False   411         4   8.0
# 5                      SIDEWALK    True     False  1414        14   1.0
# 6                        STREET   False     False   313         3  20.0
# 7  COMMERCIAL / BUSINESS OFFICE   False     False   124         1  25.0
# 8                      SIDEWALK    True     False  1821        18  27.0
# 9                      SIDEWALK   False     False  1013        10  22.0
#
#    Community Area
# 0              15
# 1              44
# 2              63
# 3              46
# 4              46
# 5              22
# 6              42
# 7              28
# 8               8
# 9              30

# %%
crime = Crimes.drop(['ID', 'Case Number'], axis = 1)
crime
# Out:
#                  Date                      Block  IUCR         Primary Type
# 0       8/17/19 23:59            058XX W EDDY ST   820                THEFT  \
# 1       8/17/19 23:59            007XX E 87TH ST  1310      CRIMINAL DAMAGE
# 2       8/17/19 23:57            022XX W 50TH PL  143A    WEAPONS VIOLATION
# 3       8/17/19 23:55       086XX S PHILLIPS AVE  143A    WEAPONS VIOLATION
# 4       8/17/19 23:45  079XX S SOUTH CHICAGO AVE   460              BATTERY
# ...               ...                        ...   ...                  ...
# 161937    1/1/19 0:00          027XX S TRIPP AVE  1562          SEX OFFENSE
# 161938    1/1/19 0:00            013XX W 72ND PL  1153   DECEPTIVE PRACTICE
# 161939    1/1/19 0:00          045XX N BEACON ST  1153   DECEPTIVE PRACTICE
# 161940    1/1/19 0:00      045XX N GREENVIEW AVE  1153   DECEPTIVE PRACTICE
# 161941    1/1/19 0:00         092XX S NORMAL AVE   910  MOTOR VEHICLE THEFT
#
#                                 Description Location Description  Arrest
# 0                            $500 AND UNDER               STREET    True  \
# 1                               TO PROPERTY  TAVERN/LIQUOR STORE   False
# 2                  UNLAWFUL POSS OF HANDGUN             SIDEWALK   False
# 3                  UNLAWFUL POSS OF HANDGUN                ALLEY   False
# 4                                    SIMPLE             SIDEWALK    True
# ...                                     ...                  ...     ...
# 161937            AGG CRIMINAL SEXUAL ABUSE            RESIDENCE    True
# 161938  FINANCIAL IDENTITY THEFT OVER $ 300            RESIDENCE   False
# 161939  FINANCIAL IDENTITY THEFT OVER $ 300            APARTMENT   False
# 161940  FINANCIAL IDENTITY THEFT OVER $ 300                OTHER   False
# 161941                           AUTOMOBILE               STREET   False
#
#         Domestic  Beat  District  Ward  Community Area
# 0          False  1633        16  36.0              15
# 1          False   632         6   6.0              44
# 2          False   931         9  15.0              63
# 3          False   423         4   7.0              46
# 4          False   411         4   8.0              46
# ...          ...   ...       ...   ...             ...
# 161937     False  1031        10  22.0              30
# 161938     False   734         7   6.0              67
# 161939     False  1913        19  46.0               3
# 161940     False  1912        19  47.0               3
# 161941     False  2223        22  21.0              73
#
# [161942 rows x 12 columns]

# %%
crime['Date_Time'] = pd.to_datetime(crime['Date'])
# Out:
# C:\Users\jamil\AppData\Local\Temp\ipykernel_11660\478394247.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crime['Date_Time'] = pd.to_datetime(crime['Date'])

# %%
crime['Year'] = crime['Date_Time'].dt.year

# %%
crime['Month'] = crime['Date_Time'].dt.month

# %%
crime['Week_Day'] = crime['Date_Time'].dt.weekday

# %%
crime['Day'] = crime['Date_Time'].dt.day

# %%
crime['Hour'] = crime['Date_Time'].dt.hour

# %%
crime['City_Block'] = crime['Block'].apply(lambda x:x.split()[0])

# %%
crime.head(5)
# Out:
#             Date                      Block  IUCR       Primary Type
# 0  8/17/19 23:59            058XX W EDDY ST   820              THEFT  \
# 1  8/17/19 23:59            007XX E 87TH ST  1310    CRIMINAL DAMAGE
# 2  8/17/19 23:57            022XX W 50TH PL  143A  WEAPONS VIOLATION
# 3  8/17/19 23:55       086XX S PHILLIPS AVE  143A  WEAPONS VIOLATION
# 4  8/17/19 23:45  079XX S SOUTH CHICAGO AVE   460            BATTERY
#
#                 Description Location Description  Arrest  Domestic  Beat
# 0            $500 AND UNDER               STREET    True     False  1633  \
# 1               TO PROPERTY  TAVERN/LIQUOR STORE   False     False   632
# 2  UNLAWFUL POSS OF HANDGUN             SIDEWALK   False     False   931
# 3  UNLAWFUL POSS OF HANDGUN                ALLEY   False     False   423
# 4                    SIMPLE             SIDEWALK    True     False   411
#
#    District  Ward  Community Area           Date_Time  Year  Month  Week_Day
# 0        16  36.0              15 2019-08-17 23:59:00  2019      8         5  \
# 1         6   6.0              44 2019-08-17 23:59:00  2019      8         5
# 2         9  15.0              63 2019-08-17 23:57:00  2019      8         5
# 3         4   7.0              46 2019-08-17 23:55:00  2019      8         5
# 4         4   8.0              46 2019-08-17 23:45:00  2019      8         5
#
#    Day  Hour City_Block
# 0   17    23      058XX
# 1   17    23      007XX
# 2   17    23      022XX
# 3   17    23      086XX
# 4   17    23      079XX

# %%
crime.dtypes
# Out:
# Date                            object
# Block                           object
# IUCR                            object
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                           float64
# Community Area                   int64
# Date_Time               datetime64[ns]
# Year                             int32
# Month                            int32
# Week_Day                         int32
# Day                              int32
# Hour                             int32
# City_Block                      object
# dtype: object

# %% [markdown]
# # Some Insights From This DataSet

# %%
#TOP 5 CRIME TYPES
((crime['Primary Type'].value_counts()/len(crime))*100).head().plot.bar()
plt.title('Top 5 Types of Crime')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crime In Percentage')

# %%
# TOP 5 CRIME LOCATIONS
((crime['Location Description'].value_counts()/len(crime))*100).head().plot.bar()
plt.title('Top 5 Crime Locations')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crime In Percentage')

# %%
# ARREST VS NO ARREST
(crime['Arrest'].value_counts()/len(crime)*100).plot.bar()
plt.title('Arrest Vs No Arrest')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')

# %%
crime_count = pd.DataFrame(crime.groupby(['Primary Type', 'Arrest']).size().sort_values(ascending = False).rename('Counts')).reset_index()
plt.figure(figsize = (10,20))
sns.barplot(y = 'Primary Type', x = 'Counts', data = crime_count, hue = 'Arrest', color = 'red')
# Out:
# <Axes: xlabel='Counts', ylabel='Primary Type'>

# %%
# TOP 5 CRIME TYPES WITH ARRESTS
arrests_by_crime = crime.groupby("Primary Type")["Arrest"].sum()
arrests_by_crime.sort_values(ascending=False).head().plot.bar()
plt.title('Number of Arrests by Crime Type')
plt.xlabel('Crime Type')
plt.ylabel('Number of Arrests')
# Out:
# Text(0, 0.5, 'Number of Arrests')

# %%
# PERCENTAGE OF DOMESTIC INCIDENTS
(crime['Domestic'].value_counts()/len(crime)*100).plot.bar()
plt.title('Domestic Incidents')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')

# %%
# DISTRICT WISE CRIME
fig = plt.figure(figsize=(10, 5))
(crime['District'].value_counts()/len(crime)*100).plot.bar()
plt.title('District Wise Crime')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')

# %%
# WARD WISE CRIME
fig = plt.figure(figsize=(15, 7))
(crime['Ward'].value_counts()/len(crime)*100).plot.bar()
plt.title('Ward Wise Crime')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')

# %%
# COMMUNITY AREA WISE CRIME
fig = plt.figure(figsize=(15, 7))
(crime['Community Area'].value_counts()/len(crime)*100).plot.bar()
plt.title('Community Area Area Wise Crime')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')

# %%
# TOP 5 IUCR CODE WISE CRIME 
((crime['IUCR'].value_counts()/len(crime))*100).head(5).plot.bar()
plt.title('Top 5 IUCR Codes Wise Crime')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')

# %%
# HOURLY CRIME RATE
fig = plt.figure(figsize=(10, 3))
(crime['Hour'].value_counts()/len(crime)*100).sort_index().plot.bar()
plt.title('Hourly Crime Rate')
plt.ylabel('Total Crimes In Percentage')
# Out:
# Text(0, 0.5, 'Total Crimes In Percentage')
